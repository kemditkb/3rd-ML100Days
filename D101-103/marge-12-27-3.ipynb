# %%
import pandas as pd

# %%
# 資料路徑
DATASET_PATH  = 'E:/git/3rd-ML100Days/D101-103/'

NEW_CVS_NAME = '5-model-2'

# %%
# NASNetLarge = pd.read_csv(DATASET_PATH+'NASNetLarge-pre-12-24.csv')
model_1=pd.read_csv(DATASET_PATH+'NASNetLarge-pre-12-24.csv')
model_1 = model_1.sort_values(by = 'id',ascending=True)
model_1.head()
# Out:
#                                  id    daisys    dandelions         roses  \
# 0  0028624c49b3e0610ff9f1d111f5d532  0.001325  1.130563e-05  9.983783e-01
# 1  002c30700185b7971369258b438070d5  0.000001  2.693699e-08  4.099620e-08
# 2  00852f4f666acecd0c0d140365b42efd  0.000007  3.967508e-06  9.996108e-01
# 3  00c08828fce04e360c732cac01edad9e  0.000093  1.016766e-07  4.369829e-06
# 4  00d366e7877b6a78b104b57d67b60e6b  0.007823  1.017901e-02  1.239580e-03
#
#      sunflowers    tulips
# 0  1.584273e-05  0.000270
# 1  9.263110e-08  0.999998
# 2  1.684739e-06  0.000377
# 3  4.492535e-05  0.999857
# 4  3.386749e-02  0.946890

# %%
model_2 = pd.read_csv(DATASET_PATH+'Xception_model_12_25-1_pre.csv')
model_2 = model_2.sort_values(by = 'id',ascending=True)
model_2.head()
# Out:
#                                  id  flower_class        daisys    dandelions  \
# 0  0028624c49b3e0610ff9f1d111f5d532             2  2.394070e-35  5.026096e-29
# 1  002c30700185b7971369258b438070d5             4  0.000000e+00  0.000000e+00
# 2  00852f4f666acecd0c0d140365b42efd             2  1.486434e-15  8.501844e-17
# 3  00c08828fce04e360c732cac01edad9e             4  1.068493e-17  9.584993e-11
# 4  00d366e7877b6a78b104b57d67b60e6b             4  8.008352e-25  6.130677e-11
#
#           roses    sunflowers        tulips
# 0  1.000000e+00  9.040489e-23  1.136384e-19
# 1  0.000000e+00  0.000000e+00  1.000000e+00
# 2  9.911346e-01  3.862377e-11  8.865295e-03
# 3  6.188249e-20  2.400493e-17  1.000000e+00
# 4  6.454307e-27  3.718305e-20  1.000000e+00

# %%
# df_all = pd.merge(NASNetLarge, model_2, how='inner', on='id')

# %%
model_3 = pd.read_csv(DATASET_PATH+'DenseNet201_model_12_26-1-val_acc_0.92_pre.csv')
model_3 = model_3.sort_values(by = 'id',ascending=True)
model_3.head()
# Out:
#                                  id  flower_class    daisys  dandelions  \
# 0  0028624c49b3e0610ff9f1d111f5d532             2  0.000415    0.000238
# 1  002c30700185b7971369258b438070d5             4  0.024561    0.023262
# 2  00852f4f666acecd0c0d140365b42efd             2  0.017711    0.017448
# 3  00c08828fce04e360c732cac01edad9e             4  0.002657    0.005842
# 4  00d366e7877b6a78b104b57d67b60e6b             4  0.195128    0.079638
#
#       roses  sunflowers    tulips
# 0  0.969440    0.001104  0.028802
# 1  0.048566    0.035288  0.868322
# 2  0.713537    0.136253  0.115052
# 3  0.027737    0.009952  0.953811
# 4  0.216632    0.073441  0.435161

# %%
model_4 = pd.read_csv(DATASET_PATH+'InceptionResNetV2_model_12_26-1checkpoint-16e-val_acc_0.96_pre.csv')
model_4 = model_4.sort_values(by = 'id',ascending=True)
model_4.head()
# df_all = pd.merge(df_all, model_4, how='inner', on='id')
# Out:
#                                  id  flower_class    daisys  dandelions  \
# 0  0028624c49b3e0610ff9f1d111f5d532             2  0.000244    0.000108
# 1  002c30700185b7971369258b438070d5             4  0.000022    0.001772
# 2  00852f4f666acecd0c0d140365b42efd             4  0.000027    0.000155
# 3  00c08828fce04e360c732cac01edad9e             4  0.001158    0.000159
# 4  00d366e7877b6a78b104b57d67b60e6b             4  0.000625    0.010539
#
#       roses  sunflowers    tulips
# 0  0.989887    0.000612  0.009148
# 1  0.000059    0.000099  0.998048
# 2  0.001606    0.000035  0.998178
# 3  0.000127    0.000031  0.998525
# 4  0.011204    0.004331  0.973301

# %%
model_5 = pd.read_csv(DATASET_PATH+'NASNetLarge_model_12_27-1.csv')
model_5 = model_4.sort_values(by = 'id',ascending=True)
model_5.head()
# Out:
#                                  id  flower_class    daisys  dandelions  \
# 0  0028624c49b3e0610ff9f1d111f5d532             2  0.000244    0.000108
# 1  002c30700185b7971369258b438070d5             4  0.000022    0.001772
# 2  00852f4f666acecd0c0d140365b42efd             4  0.000027    0.000155
# 3  00c08828fce04e360c732cac01edad9e             4  0.001158    0.000159
# 4  00d366e7877b6a78b104b57d67b60e6b             4  0.000625    0.010539
#
#       roses  sunflowers    tulips
# 0  0.989887    0.000612  0.009148
# 1  0.000059    0.000099  0.998048
# 2  0.001606    0.000035  0.998178
# 3  0.000127    0.000031  0.998525
# 4  0.011204    0.004331  0.973301

# %%
df_new = pd.DataFrame()
var_models = [model_1,model_2,model_3,model_4,model_5]
var_w = [2.5,2,2,1.5,2]
df_new['id']=model_1['id']
df_new['daisys'] = 0
df_new['dandelions'] = 0
df_new['roses'] = 0
df_new['sunflowers'] =0
df_new['tulips'] = 0


for idx,tmp_model in enumerate(var_models):
    df_new['daisys'] = df_new['daisys'] + tmp_model['daisys'] * var_w[idx]
    df_new['dandelions'] = df_new['dandelions'] + tmp_model['dandelions'] * var_w[idx]
    df_new['roses'] = df_new['roses'] + tmp_model['roses'] * var_w[idx]
    df_new['sunflowers'] = df_new['sunflowers'] + tmp_model['sunflowers'] * var_w[idx]
    df_new['tulips'] = df_new['tulips'] + tmp_model['tulips'] * var_w[idx]

df_new.head()
# Out:
#                                  id    daisys  dandelions     roses  \
# 0  0028624c49b3e0610ff9f1d111f5d532  0.004997    0.000884  9.899431
# 1  002c30700185b7971369258b438070d5  0.049204    0.052728  0.097339
# 2  00852f4f666acecd0c0d140365b42efd  0.035531    0.035448  5.913990
# 3  00c08828fce04e360c732cac01edad9e  0.009602    0.012241  0.055930
# 4  00d366e7877b6a78b104b57d67b60e6b  0.412002    0.221609  0.475577
#
#    sunflowers    tulips
# 0    0.004391  0.090298
# 1    0.070923  9.729806
# 2    0.272633  3.742398
# 3    0.020125  9.902102
# 4    0.246710  8.644101

# %%
df_new.set_index('id')

ids =[]
rf_pred =[]
for index, row in df_new.iterrows():
    a = row[['daisys','dandelions','roses','sunflowers','tulips']].as_matrix()
    result = a.argmax()
#     print (row['id'])
    ids.append(row['id'])
    rf_pred.append(result)
    
sub = pd.DataFrame({'id': ids, 'flower_class': rf_pred})
sub.to_csv(NEW_CVS_NAME, index=False)
# Out:
# d:\Anaconda3\envs\tensorflow-gpu-3.7\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
 sub.groupby("flower_class").size()
# Out:
# flower_class
# 0    367
# 1    468
# 2    371
# 3    340
# 4    454
# dtype: int64

# %%
m_new = pd.read_csv(NEW_CVS_NAME)

# %%
m_new.groupby("flower_class").size()
# Out:
# flower_class
# 0    364
# 1    478
# 2    371
# 3    346
# 4    441
# dtype: int64

# %%
ids =[]
rf_pred =[]
for index, row in NASNetLarge.iterrows():
    a = row[['daisys','dandelions','roses','sunflowers','tulips']].as_matrix()
    result = a.argmax()
#     print (row['id'])
    ids.append(row['id'])
    rf_pred.append(result)
    
sub_nas = pd.DataFrame({'id': ids, 'flower_class': rf_pred})
# Out:
# d:\Anaconda3\envs\tensorflow-gpu-3.7\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.

# %%
 sub_nas.groupby("flower_class").size()
# Out:
# flower_class
# 0    370
# 1    473
# 2    351
# 3    345
# 4    461
# dtype: int64
